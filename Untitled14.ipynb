# %% [markdown]
# <a href="https://colab.research.google.com/github/Qn-Chandra/Covid_19_prediction/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Dependencies**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Importing files into pandas Dataframe**

# %%
df=pd.read_csv('/content/covid-19 symptoms dataset.csv')

# %% [markdown]
# # **Know your data**

# %% [markdown]
# 1) How big is your Data

# %%
df.shape
# Out:
# (2575, 6)

# %% [markdown]
# 2) how does the data looks like

# %%
df.head()
# it will print top 5 rows
# Out:
#    fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 0    102         0    9          0          -1              0
# 1    102         0   10          0           0              1
# 2    104         0   33          1          -1              0
# 3    101         1   59          0           1              0
# 4     99         0   98          0           0              0

# %%
df.sample(5)
# it will print random 5 rows
# Out:
#       fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 1682    100         1    7          0           1              0
# 1063     98         1   84          1          -1              0
# 154      99         0   14          0          -1              0
# 2487     98         0   81          1           1              1
# 2245    102         0   34          1           1              1

# %% [markdown]
# 3) what is the data type of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2575 entries, 0 to 2574
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fever          2575 non-null   int64
#  1   bodyPain       2575 non-null   int64
#  2   age            2575 non-null   int64
#  3   runnyNose      2575 non-null   int64
#  4   diffBreath     2575 non-null   int64
#  5   infectionProb  2575 non-null   int64
# dtypes: int64(6)
# memory usage: 120.8 KB

# %% [markdown]
# 4) are there any missing values ?

# %%
df.isnull().sum()
# Out:
# fever            0
# bodyPain         0
# age              0
# runnyNose        0
# diffBreath       0
# infectionProb    0
# dtype: int64

# %% [markdown]
# 5. how does hte data looks mathematically

# %%
df.describe()
# Out:
#              fever     bodyPain          age    runnyNose   diffBreath  \
# count  2575.000000  2575.000000  2575.000000  2575.000000  2575.000000
# mean    100.969709     0.492816    51.023301     0.502136     0.002330
# std       1.999771     0.500045    29.014442     0.500093     0.816969
# min      98.000000     0.000000     1.000000     0.000000    -1.000000
# 25%      99.000000     0.000000    26.000000     0.000000    -1.000000
# 50%     101.000000     0.000000    50.000000     1.000000     0.000000
# 75%     103.000000     1.000000    76.500000     1.000000     1.000000
# max     104.000000     1.000000   100.000000     1.000000     1.000000
#
#        infectionProb
# count    2575.000000
# mean        0.493592
# std         0.500056
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# 6) is there any duplicate values ?

# %%
df.duplicated().sum()
# Out:
# np.int64(228)

# %% [markdown]
# 7) what is the corelation between the columns

# %%
df.corr()
# Out:
#                   fever  bodyPain       age  runnyNose  diffBreath  \
# fever          1.000000 -0.013039 -0.021883   0.011719    0.000281
# bodyPain      -0.013039  1.000000 -0.012199  -0.036059    0.005747
# age           -0.021883 -0.012199  1.000000   0.029824    0.006668
# runnyNose      0.011719 -0.036059  0.029824   1.000000    0.047533
# diffBreath     0.000281  0.005747  0.006668   0.047533    1.000000
# infectionProb -0.007187 -0.031646 -0.035496  -0.017423   -0.027542
#
#                infectionProb
# fever              -0.007187
# bodyPain           -0.031646
# age                -0.035496
# runnyNose          -0.017423
# diffBreath         -0.027542
# infectionProb       1.000000

# %% [markdown]
# # **Splitting Data into Features and Targets**

# %%
x=df.drop(columns='infectionProb', axis=1)
y=df['infectionProb']

# %%
print (x)
# Out:
#       fever  bodyPain  age  runnyNose  diffBreath
# 0       102         0    9          0          -1
# 1       102         0   10          0           0
# 2       104         0   33          1          -1
# 3       101         1   59          0           1
# 4        99         0   98          0           0
# ...     ...       ...  ...        ...         ...
# 2570     99         0   90          0           0
# 2571    100         0   53          0          -1
# 2572    101         0   44          1           0
# 2573    102         0   97          0          -1
# 2574    104         1   62          1          -1
#
# [2575 rows x 5 columns]

# %%
print(y)
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2570    1
# 2571    1
# 2572    0
# 2573    1
# 2574    1
# Name: infectionProb, Length: 2575, dtype: int64

# %% [markdown]
# # Split the data into trainning and testing data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %% [markdown]
# # **Model Training**

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train);

# %% [markdown]
# # **Model Testing**

# %%
prediction=model.predict(x_train)
accuracy=accuracy_score(prediction,y_train)

# %%
print(accuracy)
# Out:
# 0.5286407766990291
